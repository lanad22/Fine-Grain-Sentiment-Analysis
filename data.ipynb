# %%
import pytreebank
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Path to the "trees" folder
trees_folder = os.path.join(sys.path[0], 'trees')

# Load dataset from the "trees" folder
dataset = pytreebank.load_sst(trees_folder)

# Define the output path pattern
out_path_pattern = os.path.join(trees_folder, 'sst_{}.txt')

# Store train, dev and test in separate files
for category in ['train', 'test', 'dev']:
    output_path = out_path_pattern.format(category)
    with open(output_path, 'w') as outfile:
        for item in dataset[category]:
            labeled_lines = item.to_labeled_lines()
            if labeled_lines:  # Check if there are labeled lines
                label, text = labeled_lines[0]
                outfile.write("__label__{}\t{}\n".format(label + 1, text))

# Print the length of the training set
print(len(dataset['train']))
# Out:
# 8544

# %%
df = pd.read_csv('trees/sst_train.txt', sep='\t', header=None, names=['label', 'text'])
df['label'] = df['label'].str.replace('__label__', '')
df['label'] = df['label'].astype(int).astype('category')
pd.set_option('display.max_colwidth', None)
examples_per_label = df.groupby('label').apply(lambda x: x.sample(5, random_state=1)).reset_index(drop=True)

# Display the result
examples_per_label
# Out:
# /var/folders/vl/_p1j067d5fb_bp4n_tsntj8m0000gn/T/ipykernel_87611/3154457510.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   examples_per_label = df.groupby('label').apply(lambda x: x.sample(5, random_state=1)).reset_index(drop=True)
#    label  \
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# 5      2
# 6      2
# 7      2
# 8      2
# 9      2
# 10     3
# 11     3
# 12     3
# 13     3
# 14     3
# 15     4
# 16     4
# 17     4
# 18     4
# 19     4
# 20     5
# 21     5
# 22     5
# 23     5
# 24     5
#
#                                                                                                                                                                                                                            text
# 0                                                                                                                                                                                      A yawn-provoking little farm melodrama .
# 1                                                                                                                                                                                                     Does n't add up to much .
# 2                                                                                                                                                                                                    Very stupid and annoying .
# 3                                                                                                                                                                            This ludicrous film is predictable at every turn .
# 4                                                                                                                                                              Adam Sandler 's Eight Crazy Nights grows on you -- like a rash .
# 5                                                                                                                                                                                                                   A cartoon ?
# 6                                                                              The fact that the ` best part ' of the movie comes from a 60-second homage to one of Demme 's good films does n't bode well for the rest of it .
# 7                                 It 's a hellish , numbing experience to watch , and it does n't offer any insights that have n't been thoroughly debated in the media already , back in the Dahmer heyday of the mid - '90s .
# 8                                                                   Yet another entry in the sentimental oh-those-wacky-Brits genre that was ushered in by The Full Monty and is still straining to produce another smash hit .
# 9                                                                                                                                                                     Ear-splitting exercise in formula crash-and-bash action .
# 10                                                                                                                                                                                           It was a dark and stormy night ...
# 11                                                                                                                              Director David Jacobson gives Dahmer a consideration that the murderer never game his victims .
# 12                                                                                                                        The beautiful , unusual music is this film 's chief draw , but its dreaminess may lull you to sleep .
# 13                                                                                                                                                                                   Jam-packed with literally bruising jokes .
# 14                                                                                                                                                     You end up simply admiring this bit or that , this performance or that .
# 15                                                                                                                                 `` Auto Focus '' works as an unusual biopic and document of male swingers in the Playboy era
# 16                                                                                                                                                                         Smart and fun , but far more witty than it is wise .
# 17                                                                                                                                                                                                              Bravado Kathy !
# 18  If S&M seems like a strange route to true love , maybe it is , but it 's to this film 's ( and its makers ' ) credit that we believe that that 's exactly what these two people need to find each other -- and themselves .
# 19                                                                                                                                           An engaging , formulaic sports drama that carries a charge of genuine excitement .
# 20                                                                                                           An action/thriller of the finest kind , evoking memories of Day of the Jackal , The French Connection , and Heat .
# 21                                                                                                                                                                                      A movie of riveting power and sadness .
# 22                                                                                                                                                              Romanek 's themes are every bit as distinctive as his visuals .
# 23                                                                                                                           It 's crafty , energetic and smart -- the kid is sort of like a fourteen-year old Ferris Bueller .
# 24                                                                                                                                                                 ... a thoughtful what-if for the heart as well as the mind .

# %%
# Plot the distribution of labels
label_counts = df['label'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
label_counts.plot(kind='barh')
plt.title('Distribution of Labels Train Set')
plt.xlabel('Label')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
df = pd.read_csv('trees/sst_test.txt', sep='\t', header=None, names=['label', 'text'])
df['label'] = df['label'].str.replace('__label__', '')
df['label'] = df['label'].astype(int).astype('category')
pd.set_option('display.max_colwidth', None)
df.head()
# Plot the distribution of labels
label_counts = df['label'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
label_counts.plot(kind='barh',color="#8B0000")
plt.title('Distribution of Labels Test Set')
plt.xlabel('Label')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()
